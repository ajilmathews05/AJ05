# %% [markdown]
# <a href="https://colab.research.google.com/github/ajilmathews05/AJ05/blob/main/Assignement_on_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/Students_Performance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# #I.An Institution wishes to find out their student’s ability in mathematics, reading and writing skills. The Institution wants to do an exploratory study to check the following information.
#
# **A. Find out how many males and females participated in
# the test.**

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %% [markdown]
# **B. What do you think about the students' parental level of
# education? ***

# %%
df['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %% [markdown]
# **C.Who scores the most on average for math, reading and
# writing based on**
#
# **i. Gender**

# %%
df.dropna(subset=['math score','reading score','writing score'],inplace=True)

# %%
gender_scores= df.groupby('gender')[['math score','reading score','writing score']].mean()
gender_scores
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %% [markdown]
# **Who scores the most on average for math, reading and writing based on**
#
# **ii. Test preparation course**

# %%
test_preparation_course= df.groupby('test preparation course')[['math score','reading score','writing score']].mean()
test_preparation_course
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %% [markdown]
# **D. What do you think about the scoring variation for
# math, reading and writing based on**
#
# **i. Gender**

# %%
gender_scores= df.groupby('gender')[['math score','reading score','writing score']].var()
gender_scores
# Out:
#         math score  reading score  writing score
# gender
# female  256.958593     207.677438     220.369327
# male    211.889097     200.211010     202.413924

# %% [markdown]
# **D. What do you think about the scoring variation for math, reading and writing based on**
#
# **ii. test preparation course**

# %%
test_preparation_course= df.groupby('test preparation course')[['math score','reading score','writing score']].var()
test_preparation_course
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                210.884027     183.265864     175.202612
# none                     246.668662     213.419851     226.251739

# %% [markdown]
# **E.The management needs your help to give bonus points
# to the top 25% of students based on their math score,
# so how will you help the management to achieve this.**

# %%
top=df[df['math score'] >= df['math score'].quantile(0.75)]
print(top)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 414  female        group A                 high school  free/reduced
# 415  female        group B             master's degree  free/reduced
# 416  female        group B           bachelor's degree  free/reduced
# 417  female        group B             master's degree      standard
# 418  female        group B                 high school      standard
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# #II. Case Study on Testing of Hypothesis

# %% [markdown]
# **2. A company started to invest in digital marketing as a new
# way of their product promotions. For that they collected
# data and decided to carry out a study on it**
#
# **a). The company wishes to clarify whether there is any
# increase in sales after stepping into digital marketing.**

# %%
import pandas as pd
import numpy as np
data=pd.read_csv('/content/Sales_add.csv')
data
# Out:
#        Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0    Month-1  Region - A  Manager - A                          132921
# 1    Month-2  Region - A  Manager - C                          149559
# 2    Month-3  Region - B  Manager - A                          146278
# 3    Month-4  Region - B  Manager - B                          152167
# 4    Month-5  Region - C  Manager - B                          159525
# 5    Month-6  Region - A  Manager - B                          137163
# 6    Month-7  Region - C  Manager - C                          130625
# 7    Month-8  Region - A  Manager - A                          131140
# 8    Month-9  Region - B  Manager - C                          171259
# 9   Month-10  Region - C  Manager - B                          141956
# 10  Month-11  Region - B  Manager - C                          159339
# 11  Month-12  Region - A  Manager - A                          178939
# ...

# %%
data['Sales_diff'] = data['Sales_After_digital_add(in $)'] - data['Sales_before_digital_add(in $)']
data['Sales_increase_%'] = (data['Sales_diff'] / data['Sales_before_digital_add(in $)']) * 100
avg_sales_increase = data['Sales_increase_%'].mean()
print(avg_sales_increase)
# Out:
# 56.57850731561678

# %% [markdown]
# **b.The company needs to check whether there is any
# dependency between the features “Region” and “Manager”**

# %%
import pandas as pd
import scipy.stats as stats

crosstab = pd.crosstab(data['Region'], data['Manager'])

f_stat, p, dof, expected = stats.chi2_contingency(crosstab)

print("Chi-square statistic:", f_stat)
print("P-value:", p)
print("Degrees of freedom:", dof)


# Compare p-value with alpha
if p < alpha:
    print("Reject null hypothesis: There is a dependency between Region and Manager.")
else:
    print("Fail to reject null hypothesis: There is no dependency")
# Out:
# Chi-square statistic: 3.050566893424036
# P-value: 0.5493991051158094
# Degrees of freedom: 4
# Fail to reject null hypothesis: There is no dependency

# %%
p
