# %% [markdown]
# <a href="https://colab.research.google.com/github/ajilmathews05/AJ05/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AJIL MATHEWS
#
# *Numerical
#
# 1.Minimum Temp
# 2. Maximum Temperature
# 3. Rainfall
# 4. Evaporation
#
# *Categorical values
# 1.Wind Gust Direction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Weather Training Data.csv')

# %%
df[['MinTemp','MaxTemp','Rainfall','Evaporation','WindGustDir','RainToday','RainTomorrow']].sample(10)
# Out:
#        MinTemp  MaxTemp  Rainfall  Evaporation WindGustDir RainToday  \
# 15765     17.2     21.2       2.0          2.4           N       Yes
# 77269      9.7     23.5       0.0          NaN         SSE        No
# 77277     12.5     29.2       0.0          NaN           S        No
# 90240     12.5     18.8       0.0          2.4         NNW        No
# 33737     14.3     38.2       0.0          NaN         WNW        No
# 85422     14.6     21.0       2.0          NaN           E       Yes
# 62037     13.7     18.5       0.0          NaN          NW        No
# 38253     11.1     16.2       0.0          NaN         NNE        No
# 60753     24.8     32.5       2.4          5.2          SE       Yes
# 13474      9.8     18.6       1.0          NaN         SSE        No
#
#        RainTomorrow
# 15765             1
# 77269             0
# 77277             0
# 90240             0
# 33737             1
# 85422             1
# 62037             1
# 38253             0
# ...

# %%
df[['MinTemp','MaxTemp','Rainfall','Evaporation','WindGustDir','RainToday','RainTomorrow']].describe()
# Out:
#             MinTemp       MaxTemp      Rainfall  Evaporation  RainTomorrow
# count  99073.000000  99286.000000  98537.000000  56985.00000  99516.000000
# mean      12.176266     23.218513      2.353024      5.46132      0.224677
# std        6.390882      7.115072      8.487866      4.16249      0.417372
# min       -8.500000     -4.100000      0.000000      0.00000      0.000000
# 25%        7.600000     17.900000      0.000000      2.60000      0.000000
# 50%       12.000000     22.600000      0.000000      4.80000      0.000000
# 75%       16.800000     28.200000      0.800000      7.40000      0.000000
# max       33.900000     48.100000    371.000000     86.20000      1.000000

# %%
df[['MinTemp','MaxTemp','Rainfall','Evaporation','WindGustDir','RainToday','RainTomorrow']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99516 entries, 0 to 99515
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MinTemp       99073 non-null  float64
#  1   MaxTemp       99286 non-null  float64
#  2   Rainfall      98537 non-null  float64
#  3   Evaporation   56985 non-null  float64
#  4   WindGustDir   92995 non-null  object
#  5   RainToday     98537 non-null  object
#  6   RainTomorrow  99516 non-null  int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 5.3+ MB

# %%
df[['MinTemp','MaxTemp','Rainfall','Evaporation','WindGustDir','RainToday','RainTomorrow']].isna().sum()
# Out:
# MinTemp           443
# MaxTemp           230
# Rainfall          979
# Evaporation     42531
# WindGustDir      6521
# RainToday         979
# RainTomorrow        0
# dtype: int64

# %%
  df['MinTemp'].nunique()
# Out:
# 386

# %%
df['MaxTemp'].nunique()
# Out:
# 500

# %%
df['Rainfall'].nunique()
# Out:
# 601

# %%
df['Evaporation'].nunique()
# Out:
# 327

# %%
df1=df[['MinTemp','MaxTemp','Rainfall','Evaporation','WindGustDir','RainToday','RainTomorrow']].select_dtypes(include=['float','int'])
df1.corr()
# Out:
#                MinTemp   MaxTemp  Rainfall  Evaporation  RainTomorrow
# MinTemp       1.000000  0.736875  0.104381     0.472989      0.084531
# MaxTemp       0.736875  1.000000 -0.074307     0.595553     -0.159600
# Rainfall      0.104381 -0.074307  1.000000    -0.066607      0.238673
# Evaporation   0.472989  0.595553 -0.066607     1.000000     -0.115249
# RainTomorrow  0.084531 -0.159600  0.238673    -0.115249      1.000000

# %%
import seaborn as sns
corrmat=df1.corr();
sns.heatmap(corrmat,annot=True,cmap='YlGnBu',linewidth=0.2);
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 1. Univariate and Bi-variate analysis of MinTemp

# %%
plt.subplots(figsize=(10,5))
sns.histplot(df['MinTemp'])
plt.xticks(rotation=90);

# %%
sns.displot(kind='hist',data=df,x='MinTemp',hue='RainTomorrow',kde=True)

# %%
sns.boxplot(data=df,x='RainTomorrow',y='MinTemp')
# Out:
# <Axes: xlabel='RainTomorrow', ylabel='MinTemp'>

# %% [markdown]
# # 2.Univariate and Bivariate Analysis of MaxTemp

# %%
plt.subplots(figsize=(10,5))
sns.histplot(df['MaxTemp'])
plt.xticks(rotation=90)
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
sns.displot(kind='hist',data=df,x='MaxTemp',hue='RainTomorrow',kde=True)

# %%
sns.boxplot(data=df,x='RainTomorrow',y='MaxTemp')
# Out:
# <Axes: xlabel='RainTomorrow', ylabel='MaxTemp'>

# %% [markdown]
# # 3.Univariate and Bivariate analysis of Rainfall

# %%
sns.histplot(data=df,x='Rainfall',bins=10)
# Out:
# <Axes: xlabel='Rainfall', ylabel='Count'>

# %%
sns.histplot(data=df,x='Rainfall',hue='RainTomorrow')
# Out:
# <Axes: xlabel='Rainfall', ylabel='Count'>

# %%
sns.boxplot(data=df,x='RainTomorrow',y='Rainfall')
# Out:
# <Axes: xlabel='RainTomorrow', ylabel='Rainfall'>

# %% [markdown]
# ## 4.Univariate and Bivariate analysis of Evaporation

# %%
plt.subplots(figsize=(10,5))
sns.histplot(df['Evaporation'])
plt.xticks(rotation=90);

# %%
sns.displot(kind='hist',data=df,x='Evaporation',hue='RainTomorrow',kde=True)

# %%
sns.boxplot(data=df,x='RainTomorrow',y='Evaporation')
# Out:
# <Axes: xlabel='RainTomorrow', ylabel='Evaporation'>

# %% [markdown]
# # 5. Univariate and Bivariate analysis of Categorical values(WindGustDir)

# %%
df['WindGustDir'].unique()
# Out:
# array(['W', 'WNW', 'N', 'NNE', 'SW', 'ENE', 'SSE', 'NE', 'WSW', 'NNW',
#        'S', 'ESE', nan, 'NW', 'E', 'SSW', 'SE'], dtype=object)

# %%
df['WindGustDir'].nunique()
# Out:
# 16

# %%
plt.subplots(figsize=(10,5))
sns.histplot(df['WindGustDir'])
plt.xticks(rotation=90);

# %%
sns.displot(kind='hist',data=df,x='WindGustDir',hue='RainTomorrow',kde=True)
plt.xticks(rotation=90);
